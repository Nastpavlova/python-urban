# %% [markdown]
# <a href="https://colab.research.google.com/github/Nastpavlova/python-urban/blob/main/%D0%97%D0%B0%D1%87%D1%91%D1%82%D0%BD%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Итоговый проект. Улицы. Объекты культурного наследия.

# %%
#установим необходимое для работы
# !pip install folium -U
# !pip install geopandas mapclassify osmnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.28.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2022.9.24)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.7/dist-packages (2.4.3)
# Requirement already satisfied: osmnx in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.4)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.21)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.4)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from mapclassify) (2.6.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from mapclassify) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from mapclassify) (1.7.3)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.28.1)
# Requirement already satisfied: Rtree>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.0.1)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.5.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (7.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.4->osmnx) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify) (1.2.0)

# %%
#подключим необходимые для работы библиотеки, которые не входят в стандартный набор

import pandas as pd
import geopandas as gpd
import osmnx as ox

# %%
#константа, чтобы везде была одна и таже подложка карт
TILES = "CartoDB positron"

#данные, с которыми будет идти работа в проекте, в одном месте
TERRITORY_NAME = 'Московский район, Санкт-Петербург'
STREETS_FILE_URL = "https://drive.google.com/file/d/1bUT1E-QSbG1vpSNM2dOG2-LEVXSrPdo3/view?usp=sharing"
KGIOP_FILE_URL = "https://raw.githubusercontent.com/Nastpavlova/python-urban/main/kgiop_objects.geojson"

# %%
def get_google_drive_download_url(url: str) -> str: #Функция возвращает ссылку для скачивания с google drive
    drive_id = url.split("/")[5]
    return f"https://drive.google.com/uc?export=download&id={drive_id}"

# %% [markdown]
# # Территория

# %% [markdown]
# ## Загрузка территории из OSM (Extract)

# %%
#выбрала Московский раойн, далее выгружу его из OpenStreetMap и визуализирую 
territory = ox.geocode_to_gdf(TERRITORY_NAME)  #датафрейм с геотмерией Московского района
territory.explore(color='purple', tiles=TILES) #визуализируем данные в фиолетовом цвете
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_445599dd01352a6db951781e431e01b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_445599dd01352a6db951781e431e01b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_445599dd01352a6db951781e431e01b4 = L.map(
#                 &quot;map_445599dd01352a6db951781e431e01b4&quot;,
#                 {
#                     center: [59.828599749999995, 30.29021345],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_445599dd01352a6db951781e431e01b4);
#
#
#
#
#
#             var tile_layer_6fecd57c45eefc080ce5d329088ee98f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_445599dd01352a6db951781e431e01b4);
#
#
#             map_445599dd01352a6db951781e431e01b4.fitBounds(
#                 [[59.7441481, 30.1987721], [59.9130514, 30.3816548]],
#                 {}
#             );
#
#
#         function geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b1e67fb10a3c3ae7c49ddcec7a670467.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b1e67fb10a3c3ae7c49ddcec7a670467 = L.geoJson(null, {
#                 onEachFeature: geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_onEachFeature,
#
#                 style: geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_styler,
#                 pointToLayer: geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_pointToLayer
#         });
#
#         function geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_add (data) {
#             geo_json_b1e67fb10a3c3ae7c49ddcec7a670467
#                 .addData(data)
#                 .addTo(map_445599dd01352a6db951781e431e01b4);
#         }
#             geo_json_b1e67fb10a3c3ae7c49ddcec7a670467_add({&quot;bbox&quot;: [30.1987721, 59.7441481, 30.3816548, 59.9130514], &quot;features&quot;: [{&quot;bbox&quot;: [30.1987721, 59.7441481, 30.3816548, 59.9130514], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.1987721, 59.8016053], [30.1988845, 59.8015212], [30.1991435, 59.8014813], [30.1993875, 59.8014132], [30.1997215, 59.8014109], [30.1998699, 59.801385], [30.1999383, 59.8013343], [30.2000009, 59.8012465], [30.2000703, 59.8010976], [30.2001212, 59.8008743], [30.2002638, 59.8001769], [30.2002154, 59.8000436], [30.2001445, 59.7998133], [30.2001762, 59.7997278], [30.2002634,

# %% [markdown]
# # Улицы

# %% [markdown]
# ## Загрузка файла с улицами из google disk (Extract)

# %%
url = get_google_drive_download_url(STREETS_FILE_URL) #файл с улицами из google disk мы прописывали в начале (STREETS_FILE_URL = "https://drive.google.com/file/d/1bUT1E-QSbG1vpSNM2dOG2-LEVXSrPdo3/view?usp=sharing")
gdf_streets = gpd.read_file(url, mask=territory)  #фильтруем улицы по маске геометрии территории
gdf_streets
# Out:
#       type         id                                               tags  \
# 0      way    4454679  {'foot': 'no', 'highway': 'residential', 'lane...
# 1      way    4455257  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 2      way    4456250  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 3      way    4456529  {'highway': 'trunk', 'int_ref': 'E 95', 'lanes...
# 4      way    4457455  {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# ...    ...        ...                                                ...
# 10657  way  983206165   {'highway': 'residential', 'name': '26-я линия'}
# 10658  way  983235002                             {'highway': 'service'}
# 10659  way  983235003                             {'highway': 'service'}
# 10660  way  983236061        {'access': 'private', 'highway': 'service'}
# 10661  way  983236146                             {'highway': 'service'}
#
#                                                 geometry
# 0      LINESTRING (3376114.437 8372845.795, 3376115.2...
# 1      LINESTRING (3373432.261 8367053.679, 3373385.1...
# 2      LINESTRING (3373190.720 8367201.523, 3373256.3...
# 3      LINESTRING (3375634.027 8355843.811, 3375635.6...
# 4      LINESTRING (3379846.768 8367371.582, 3379829.6...
# ...                                                  ...
# 10657  LINESTRING (3367405.669 8360587.214, 3367396.6...
# 10658  LINESTRING (3371676.463 8361986.839, 3371707.2...
# 10659  LINESTRING (3371843.309 8361636.365, 3371869.1...
# 10660  LINESTRING (3370177.190 8363516.976, 3370183.2...
# 10661  LINESTRING (3371157.614 8363083.686, 3371238.0...
#
# [10662 rows x 4 columns]

# %% [markdown]
# # Обработка данных с улицами (Transform)

# %% [markdown]
# С помощью json_normalize преобразовываю вложенные структуры данных в json файле в таблицу.

# %%
tags = pd.json_normalize(gdf_streets["tags"])
tags
# Out:
#       foot      highway lanes  lit  maxspeed                     name oneway  \
# 0       no  residential     2  yes  RU:urban       улица Севастьянова    yes
# 1       no    secondary     2  yes  RU:urban  Краснопутиловская улица    yes
# 2       no    secondary     2  yes  RU:urban  Краснопутиловская улица    yes
# 3      NaN        trunk     5  yes  RU:urban         Пулковское шоссе    yes
# 4       no     tertiary     2  yes  RU:urban       Витебский проспект    NaN
# ...    ...          ...   ...  ...       ...                      ...    ...
# 10657  NaN  residential   NaN  NaN       NaN               26-я линия    NaN
# 10658  NaN      service   NaN  NaN       NaN                      NaN    NaN
# 10659  NaN      service   NaN  NaN       NaN                      NaN    NaN
# 10660  NaN      service   NaN  NaN       NaN                      NaN    NaN
# 10661  NaN      service   NaN  NaN       NaN                      NaN    NaN
#
#        surface parking:lane:right trolley_wire  ... lanes:forward  \
# 0      asphalt                NaN          NaN  ...           NaN
# 1      asphalt        no_stopping          yes  ...           NaN
# 2      asphalt        no_stopping          yes  ...           NaN
# 3      asphalt                NaN          NaN  ...           NaN
# 4      asphalt                NaN          NaN  ...           NaN
# ...        ...                ...          ...  ...           ...
# 10657      NaN                NaN          NaN  ...           NaN
# 10658      NaN                NaN          NaN  ...           NaN
# 10659      NaN                NaN          NaN  ...           NaN
# 10660      NaN                NaN          NaN  ...           NaN
# 10661      NaN                NaN          NaN  ...           NaN
#
#       turn:lanes:forward maxheight:hgv previous:vehicle construction  \
# 0                    NaN           NaN              NaN          NaN
# 1                    NaN           NaN              NaN          NaN
# 2                    NaN           NaN              NaN          NaN
# 3                    NaN           NaN              NaN          NaN
# 4                    NaN           NaN              NaN          NaN
# ...                  ...           ...              ...          ...
# 10657                NaN           NaN              NaN          NaN
# 10658                NaN           NaN              NaN          NaN
# 10659                NaN           NaN              NaN          NaN
# 10660                NaN           NaN              NaN          NaN
# 10661                NaN           NaN              NaN          NaN
#
#       source:name turn:backward turn:forward proposed:oneway  \
# 0             NaN           NaN          NaN             NaN
# 1             NaN           NaN          NaN             NaN
# 2             NaN           NaN          NaN             NaN
# 3             NaN           NaN          NaN             NaN
# 4             NaN           NaN          NaN             NaN
# ...           ...           ...          ...             ...
# 10657         NaN           NaN          NaN             NaN
# 10658         NaN           NaN          NaN             NaN
# 10659         NaN           NaN          NaN             NaN
# 10660         NaN           NaN          NaN             NaN
# 10661         NaN           NaN          NaN             NaN
#
#       construction:bridge
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 10657                 NaN
# 10658                 NaN
# 10659                 NaN
# 10660                 NaN
# 10661                 NaN
#
# [10662 rows x 106 columns]

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10662 entries, 0 to 10661
# Columns: 106 entries, foot to construction:bridge
# dtypes: object(106)
# memory usage: 8.6+ MB

# %%
#Из всех тегов оставим только теги name и name:ru.
extract_tags = [
    "name", 
]

#прицепляю теги к улицам с помощью метода join
gdf_streets = gdf_streets.join(tags[extract_tags])
gdf_streets
# Out:
#       type         id                                               tags  \
# 0      way    4454679  {'foot': 'no', 'highway': 'residential', 'lane...
# 1      way    4455257  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 2      way    4456250  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 3      way    4456529  {'highway': 'trunk', 'int_ref': 'E 95', 'lanes...
# 4      way    4457455  {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# ...    ...        ...                                                ...
# 10657  way  983206165   {'highway': 'residential', 'name': '26-я линия'}
# 10658  way  983235002                             {'highway': 'service'}
# 10659  way  983235003                             {'highway': 'service'}
# 10660  way  983236061        {'access': 'private', 'highway': 'service'}
# 10661  way  983236146                             {'highway': 'service'}
#
#                                                 geometry  \
# 0      LINESTRING (3376114.437 8372845.795, 3376115.2...
# 1      LINESTRING (3373432.261 8367053.679, 3373385.1...
# 2      LINESTRING (3373190.720 8367201.523, 3373256.3...
# 3      LINESTRING (3375634.027 8355843.811, 3375635.6...
# 4      LINESTRING (3379846.768 8367371.582, 3379829.6...
# ...                                                  ...
# 10657  LINESTRING (3367405.669 8360587.214, 3367396.6...
# 10658  LINESTRING (3371676.463 8361986.839, 3371707.2...
# 10659  LINESTRING (3371843.309 8361636.365, 3371869.1...
# 10660  LINESTRING (3370177.190 8363516.976, 3370183.2...
# 10661  LINESTRING (3371157.614 8363083.686, 3371238.0...
#
#                           name
# 0           улица Севастьянова
# 1      Краснопутиловская улица
# 2      Краснопутиловская улица
# 3             Пулковское шоссе
# 4           Витебский проспект
# ...                        ...
# 10657               26-я линия
# 10658                      NaN
# 10659                      NaN
# 10660                      NaN
# 10661                      NaN
#
# [10662 rows x 5 columns]

# %%
#удалим те улицы, у которых нет названия.
gdf_streets.dropna(
    how="all",  # удалить если отсутствуют значения во всех указанных столбцах
    subset=["name"],  # столбцы, в которых надо искать пропуски
    inplace=True
)
gdf_streets
# Out:
#       type         id                                               tags  \
# 0      way    4454679  {'foot': 'no', 'highway': 'residential', 'lane...
# 1      way    4455257  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 2      way    4456250  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 3      way    4456529  {'highway': 'trunk', 'int_ref': 'E 95', 'lanes...
# 4      way    4457455  {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# ...    ...        ...                                                ...
# 10643  way  980878664  {'highway': 'residential', 'name': 'Средняя Са...
# 10644  way  980878665  {'highway': 'residential', 'name': 'Косая алле...
# 10645  way  980878666  {'highway': 'residential', 'name': 'Речная алл...
# 10649  way  981974253  {'highway': 'unclassified', 'lanes': '1', 'max...
# 10657  way  983206165   {'highway': 'residential', 'name': '26-я линия'}
#
#                                                 geometry  \
# 0      LINESTRING (3376114.437 8372845.795, 3376115.2...
# 1      LINESTRING (3373432.261 8367053.679, 3373385.1...
# 2      LINESTRING (3373190.720 8367201.523, 3373256.3...
# 3      LINESTRING (3375634.027 8355843.811, 3375635.6...
# 4      LINESTRING (3379846.768 8367371.582, 3379829.6...
# ...                                                  ...
# 10643  LINESTRING (3369803.914 8362270.100, 3369811.6...
# 10644  LINESTRING (3369844.356 8362212.530, 3369859.1...
# 10645  LINESTRING (3369979.887 8362045.249, 3369962.8...
# 10649  LINESTRING (3373466.982 8364365.242, 3373469.9...
# 10657  LINESTRING (3367405.669 8360587.214, 3367396.6...
#
#                           name
# 0           улица Севастьянова
# 1      Краснопутиловская улица
# 2      Краснопутиловская улица
# 3             Пулковское шоссе
# 4           Витебский проспект
# ...                        ...
# 10643    Средняя Садовая улица
# 10644              Косая аллея
# 10645             Речная аллея
# 10649  2-й Предпортовый проезд
# 10657               26-я линия
#
# [1721 rows x 5 columns]

# %% [markdown]
# Проверим наличие дубликатов в "id", "geometry", "name"

# %%
gdf_streets.duplicated(subset=["id", "geometry", "name"]).value_counts()
# Out:
# False    1721
# dtype: int64

# %% [markdown]
# Проверим, являются ли названия улиц уникальными.

# %%
gdf_streets["name"].is_unique
# Out:
# False

# %% [markdown]
# Сгруппируем геометрии по столбцу name и объединим геометрии в одну с помощью метода dissolve

# %%
gdf_streets = gdf_streets.dissolve(by="name")
gdf_streets
# Out:
#                                                                   geometry  \
# name
# 0-я линия                MULTILINESTRING ((3369124.063 8361843.816, 336...
# 1-й Предпортовый проезд  MULTILINESTRING ((3373081.627 8365227.987, 337...
# 1-я аллея                MULTILINESTRING ((3368591.989 8361184.182, 336...
# 1-я линия                MULTILINESTRING ((3368791.118 8362213.815, 336...
# 10-я линия               MULTILINESTRING ((3368567.811 8361154.814, 336...
# ...                                                                    ...
# улица Севастьянова       MULTILINESTRING ((3376114.437 8372845.795, 337...
# улица Типанова           MULTILINESTRING ((3376280.682 8367185.099, 337...
# улица Титова             MULTILINESTRING ((3377213.996 8367358.681, 337...
# улица Фрунзе             MULTILINESTRING ((3375329.034 8369015.133, 337...
# улица Фёдора Котанова    LINESTRING (3377798.378 8361194.038, 3377855.7...
#
#                         type         id  \
# name
# 0-я линия                way  137816726
# 1-й Предпортовый проезд  way   35967288
# 1-я аллея                way   93773849
# 1-я линия                way  137816727
# 10-я линия               way   93773842
# ...                      ...        ...
# улица Севастьянова       way    4454679
# улица Типанова           way   31399625
# улица Титова             way    4458329
# улица Фрунзе             way   31364976
# улица Фёдора Котанова    way  759621636
#
#                                                                       tags
# name
# 0-я линия                {'addr:suburb': 'сдт «Дачное» Балтийского заво...
# 1-й Предпортовый проезд  {'highway': 'residential', 'lanes': '2', 'lit'...
# 1-я аллея                {'highway': 'service', 'name': '1-я аллея', 's...
# 1-я линия                {'access': 'private', 'addr:suburb': 'сдт «Дач...
# 10-я линия               {'addr:suburb': 'сдт «Дачное» Балтийского заво...
# ...                                                                    ...
# улица Севастьянова       {'foot': 'no', 'highway': 'residential', 'lane...
# улица Типанова           {'cycleway:right': 'share_busway', 'foot': 'no...
# улица Титова             {'highway': 'residential', 'lanes': '1', 'lit'...
# улица Фрунзе             {'highway': 'tertiary', 'lanes': '4', 'lit': '...
# улица Фёдора Котанова    {'highway': 'residential', 'name': 'улица Фёдо...
#
# [173 rows x 4 columns]

# %%
gdf_streets.index.rename("Название улицы", inplace=True)
gdf_streets.head()
# Out:
#                                                                   geometry  \
# Название улицы
# 0-я линия                MULTILINESTRING ((3369124.063 8361843.816, 336...
# 1-й Предпортовый проезд  MULTILINESTRING ((3373081.627 8365227.987, 337...
# 1-я аллея                MULTILINESTRING ((3368591.989 8361184.182, 336...
# 1-я линия                MULTILINESTRING ((3368791.118 8362213.815, 336...
# 10-я линия               MULTILINESTRING ((3368567.811 8361154.814, 336...
#
#                         type         id  \
# Название улицы
# 0-я линия                way  137816726
# 1-й Предпортовый проезд  way   35967288
# 1-я аллея                way   93773849
# 1-я линия                way  137816727
# 10-я линия               way   93773842
#
#                                                                       tags
# Название улицы
# 0-я линия                {'addr:suburb': 'сдт «Дачное» Балтийского заво...
# 1-й Предпортовый проезд  {'highway': 'residential', 'lanes': '2', 'lit'...
# 1-я аллея                {'highway': 'service', 'name': '1-я аллея', 's...
# 1-я линия                {'access': 'private', 'addr:suburb': 'сдт «Дач...
# 10-я линия               {'addr:suburb': 'сдт «Дачное» Балтийского заво...

# %% [markdown]
# Удалим ненужные столбцы ("id", "type" и "tags") из датафрейма с улицами. Оставляем только "название улицы" и "geometry"

# %%
drop_columns = [
    "id",
    "type", 
    "tags",
]
gdf_streets.drop(columns=drop_columns, inplace=True)
gdf_streets.head()
# Out:
#                                                                   geometry
# Название улицы
# 0-я линия                MULTILINESTRING ((3369124.063 8361843.816, 336...
# 1-й Предпортовый проезд  MULTILINESTRING ((3373081.627 8365227.987, 337...
# 1-я аллея                MULTILINESTRING ((3368591.989 8361184.182, 336...
# 1-я линия                MULTILINESTRING ((3368791.118 8362213.815, 336...
# 10-я линия               MULTILINESTRING ((3368567.811 8361154.814, 336...

# %%
gdf_streets.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d75458836b2914d42a1f06312590af43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d75458836b2914d42a1f06312590af43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d75458836b2914d42a1f06312590af43 = L.map(
#                 &quot;map_d75458836b2914d42a1f06312590af43&quot;,
#                 {
#                     center: [59.8282928, 30.29953855],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d75458836b2914d42a1f06312590af43);
#
#
#
#
#
#             var tile_layer_030bd9ebeac7b9cbd950dba4945b15a7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d75458836b2914d42a1f06312590af43);
#
#
#             map_d75458836b2914d42a1f06312590af43.fitBounds(
#                 [[59.743432999999996, 30.215627800000004], [59.9131526, 30.3834493]],
#                 {}
#             );
#
#
#         function geo_json_79619b2a05bd0dd334b0289fe28d0345_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_79619b2a05bd0dd334b0289fe28d0345_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_79619b2a05bd0dd334b0289fe28d0345_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_79619b2a05bd0dd334b0289fe28d0345_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_79619b2a05bd0dd334b0289fe28d0345_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_79619b2a05bd0dd334b0289fe28d0345.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_79619b2a05bd0dd334b0289fe28d0345_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_79619b2a05bd0dd334b0289fe28d0345 = L.geoJson(null, {
#                 onEachFeature: geo_json_79619b2a05bd0dd334b0289fe28d0345_onEachFeature,
#
#                 style: geo_json_79619b2a05bd0dd334b0289fe28d0345_styler,
#                 pointToLayer: geo_json_79619b2a05bd0dd334b0289fe28d0345_pointToLayer
#         });
#
#         function geo_json_79619b2a05bd0dd334b0289fe28d0345_add (data) {
#             geo_json_79619b2a05bd0dd334b0289fe28d0345
#                 .addData(data)
#                 .addTo(map_d75458836b2914d42a1f06312590af43);
#         }
#             geo_json_79619b2a05bd0dd334b0289fe28d0345_add({&quot;bbox&quot;: [30.215627800000004, 59.743432999999996, 30.3834493, 59.9131526], &quot;features&quot;: [{&quot;bbox&quot;: [30.263860100000002, 59.82930149999999, 30.265493999999993, 59.8301903], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.265356399999995, 59.829357499999986], [30.265493999999993, 59.82930149999999]], [[30.263860100000002, 59.8301903], [30.265356399999995, 59.829357499999986]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;\u041d\u0430\u0437\u0432\u0430\u043d\u0438\u0435 \u0443\u043b\u0438\u0446\u044b&quot;: &quot;0-\u044f \u043b\u0438\u043d\u0438\u044f&quot

# %% [markdown]
# # Объекты культурного наследия

# %% [markdown]
# ## Загрузка объектов культурного наследия

# %%
gdf_kgiop_objects = gpd.read_file(KGIOP_FILE_URL, mask=territory)
gdf_kgiop_objects
# Out:
#        id                                      ensemble_name  \
# 0     478                                                  —
# 1     481  Митрофаниевское кладбище (православное и лютер...
# 2     482  Митрофаниевское кладбище (православное и лютер...
# 3    3622                                                  —
# 4    3598                                                  —
# ..    ...                                                ...
# 326  7340                  Сооружения рубежа "Ижора" 1943 г.
# 327  7364                   Сооружения периода 1941-1943 гг.
# 328  9561                                                  —
# 329  9668                                Доты рубежа «Ижора»
# 330  9669                                                  —
#
#                                            object_name  occurrence_time  \
# 0    Митрофаниевское кладбище (православное и лютер...        1864-1902
# 1                                                Склеп                —
# 2                                             Кладбище                —
# 3    Комплекс построек городского механического хле...  1915-1916, 1918
# 4    Братское захоронение воинов Советской Армии, п...                —
# ..                                                 ...              ...
# 326                            ДОТ № 75 рубежа "Ижора"             1943
# 327                                 ДОТ артиллерийский        1941-1943
# 328       Две казармы для служащих Варшавского вокзала                —
# 329                                            Дот №58        1941-1944
# 330                                Доты рубежа «Ижора»        1941-1944
#
#                                        object_location  \
# 0    Митрофаньевское шоссе, д.4, 6, 8, 10, 16 (Митр...
# 1             Митрофаньевское шоссе, д.4, 6, 8, 10, 16
# 2    Митрофаньевское шоссе, д.4, 6, 8, 10, 16; квар...
# 3                         Малая Митрофаньевская ул., 4
# 4                                          Авиагородок
# ..                                                 ...
# 326                          ул. Типанова, возле д. 25
# 327  600 м юго-западнее здания по адресу: Московско...
# 328  Малая Митрофаньевская ул., два дома без номера...
# 329    Пулковское шоссе, дом 2, сооружение 2, литера А
# 330  (Ленинский пр., у дома 138 (ДОТ №103), пр. Юри...
#
#                                    historical_category  \
# 0    объект культурного наследия регионального знач...
# 1    объект культурного наследия регионального знач...
# 2    объект культурного наследия регионального знач...
# 3               выявленный объект культурного наследия
# 4    объект культурного наследия регионального знач...
# ..                                                 ...
# 326  объект культурного наследия регионального знач...
# 327  объект культурного наследия регионального знач...
# 328             выявленный объект культурного наследия
# 329             выявленный объект культурного наследия
# 330             выявленный объект культурного наследия
#
#                                          normative_act object_type  \
# 0             Распоряжение КГИОП № 10-97 от 04.03.2014    Ансамбль
# 1             Распоряжение КГИОП № 10-97 от 04.03.2014    Памятник
# 2             Распоряжение КГИОП № 10-97 от 04.03.2014    Памятник
# 3         Приказ председателя КГИОП № 15 от 20.02.2001    Ансамбль
# 4    Решение исполкома Ленгорсовета № 328 от 03.05....    Памятник
# ..                                                 ...         ...
# 326          Распоряжение КГИОП № 10-192 от 07.05.2015    Памятник
# 327          Распоряжение КГИОП № 10-192 от 07.05.2015    Памятник
# 328           Распоряжение КГИОП от 29.12.2018 № 560-р    Памятник
# 329           Распоряжение КГИОП № 136-р от 22.04.2021    Памятник
# 330           Распоряжение КГИОП № 136-р от 22.04.2021    Ансамбль
#
#                             geometry
# 0    POINT (3373155.231 8376583.125)
# 1    POINT (3372776.188 8376619.079)
# 2    POINT (3373365.514 8376570.252)
# 3    POINT (3374857.863 8376646.378)
# 4    POINT (3372484.309 8358734.316)
# ..                               ...
# 326  POINT (3378330.808 8367347.975)
# 327  POINT (3379888.836 8358970.780)
# 328  POINT (3373659.620 8376605.097)
# 329  POINT (3375601.588 8364465.593)
# 330  POINT (3375601.588 8364465.593)
#
# [331 rows x 9 columns]

# %%
gdf_kgiop_objects.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f607b5b42ca3401bee017c069250ecd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f607b5b42ca3401bee017c069250ecd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f607b5b42ca3401bee017c069250ecd3 = L.map(
#                 &quot;map_f607b5b42ca3401bee017c069250ecd3&quot;,
#                 {
#                     center: [59.83774149999999, 30.313424000000005],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f607b5b42ca3401bee017c069250ecd3);
#
#
#
#
#
#             var tile_layer_adf43788c51d3ed616a12c0bea5fe9ac = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f607b5b42ca3401bee017c069250ecd3);
#
#
#             map_f607b5b42ca3401bee017c069250ecd3.fitBounds(
#                 [[59.76378, 30.264790000000005], [59.91170299999999, 30.362058]],
#                 {}
#             );
#
#
#         function geo_json_18ba0e2ec701a29a3d7181e30261ae33_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_18ba0e2ec701a29a3d7181e30261ae33_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_18ba0e2ec701a29a3d7181e30261ae33_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_18ba0e2ec701a29a3d7181e30261ae33_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_18ba0e2ec701a29a3d7181e30261ae33_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_18ba0e2ec701a29a3d7181e30261ae33.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_18ba0e2ec701a29a3d7181e30261ae33_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_18ba0e2ec701a29a3d7181e30261ae33 = L.geoJson(null, {
#                 onEachFeature: geo_json_18ba0e2ec701a29a3d7181e30261ae33_onEachFeature,
#
#                 style: geo_json_18ba0e2ec701a29a3d7181e30261ae33_styler,
#                 pointToLayer: geo_json_18ba0e2ec701a29a3d7181e30261ae33_pointToLayer
#         });
#
#         function geo_json_18ba0e2ec701a29a3d7181e30261ae33_add (data) {
#             geo_json_18ba0e2ec701a29a3d7181e30261ae33
#                 .addData(data)
#                 .addTo(map_f607b5b42ca3401bee017c069250ecd3);
#         }
#             geo_json_18ba0e2ec701a29a3d7181e30261ae33_add({&quot;bbox&quot;: [30.264790000000005, 59.76378, 30.362058, 59.91170299999999], &quot;features&quot;: [{&quot;bbox&quot;: [30.301569, 59.895834999999984, 30.301569, 59.895834999999984], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.301569, 59.895834999999984], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;ensemble_name&quot;: &quot;\u2014&quot;, &quot;historical_category&quot;: &quot;\u043e\u0431\u044a\u0435\u043a\u0442 \u043a\u0443\u043b\u044c\u0442\u0443\u0440\u043d\u043e\u0433\u043e \u043d\u0430\u0441\u043b\u0435\u0434\u0438\u044f \u0440\u0435\u0433\u0438\u043e\u043d\u0430\u043b\

# %%
STREET_BUFFER = 100

def get_contains_kgiop_objects(street) -> int:
    """ Функция для подсчета количества объектов культурного наследия попадающих в буффер улицы"""
    return sum(gdf_kgiop_objects["geometry"].within(street.buffer(STREET_BUFFER)))


gdf_streets["contains_kgiop_objects"] = gdf_streets["geometry"].apply(get_contains_kgiop_objects)
gdf_streets.nlargest(5, "contains_kgiop_objects")
# Out:
#                type         id  \
# Название улицы
# 2594            way  142142191
# 2601            way  142147527
# 5527            way  309153689
# 5739            way  323757908
# 9082            way  778228482
#
#                                                              tags  \
# Название улицы
# 2594            {'foot': 'no', 'highway': 'primary', 'int_ref'...
# 2601            {'foot': 'no', 'highway': 'primary', 'int_ref'...
# 5527            {'hgv': 'no', 'highway': 'tertiary', 'lanes': ...
# 5739            {'addr:postcode': '196084', 'highway': 'unclas...
# 9082            {'foot': 'no', 'highway': 'secondary', 'lanes'...
#
#                                                          geometry  \
# Название улицы
# 2594            LINESTRING (3375215.455 8371228.225, 3375216.9...
# 2601            LINESTRING (3375308.696 8369705.357, 3375297.1...
# 5527            LINESTRING (3374645.532 8375704.648, 3374667.4...
# 5739            LINESTRING (3375188.237 8375905.638, 3375369.9...
# 9082            LINESTRING (3375043.744 8379349.488, 3375075.3...
#
#                                        name  contains_kgiop_objects
# Название улицы
# 2594                    Московский проспект                       7
# 2601                    Московский проспект                       5
# 5527                      Ташкентская улица                       5
# 5739                     Черниговская улица                       4
# 9082            набережная Обводного канала                       4

# %%
gdf_streets.explore("contains_kgiop_objects", tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3dfcd981d378eb93072482f5564875d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3dfcd981d378eb93072482f5564875d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c3dfcd981d378eb93072482f5564875d = L.map(
#                 &quot;map_c3dfcd981d378eb93072482f5564875d&quot;,
#                 {
#                     center: [59.8282928, 30.29953855],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c3dfcd981d378eb93072482f5564875d);
#
#
#
#
#
#             var tile_layer_da15d9710d56f7d3f9f99ecc66a68219 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c3dfcd981d378eb93072482f5564875d);
#
#
#             map_c3dfcd981d378eb93072482f5564875d.fitBounds(
#                 [[59.743432999999996, 30.215627800000004], [59.9131526, 30.3834493]],
#                 {}
#             );
#
#
#         function geo_json_e308c58eb817f9f1dcd911db2b7631c2_styler(feature) {
#             switch(feature.id) {
#                 case &quot;50&quot;: case &quot;55&quot;: case &quot;110&quot;: case &quot;137&quot;: case &quot;149&quot;: case &quot;151&quot;: case &quot;157&quot;: case &quot;160&quot;:
#                     return {&quot;color&quot;: &quot;#482071&quot;, &quot;fillColor&quot;: &quot;#482071&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;52&quot;: case &quot;67&quot;: case &quot;109&quot;: case &quot;112&quot;: case &quot;129&quot;: case &quot;132&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;153&quot;: case &quot;163&quot;: case &quot;166&quot;: case &quot;172&quot;:
#                     return {&quot;color&quot;: &quot;#471164&quot;, &quot;fillColor&quot;: &quot;#471164&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;68&quot;: case &quot;75&quot;: case &quot;90&quot;: case &quot;125&quot;:
#                     return {&quot;color&quot;: &quot;#472e7c&quot;, &quot;fillColor&quot;: &quot;#472e7c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;77&quot;: case &quot;119&quot;: case &quot;139&quot;: case &quot;145&quot;:
#                     return {&quot;color&quot;: &quot;#443b84&quot;, &quot;fillColor&quot;: &quot;#443b84&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;92&quot;: case &quot;105&quot;: case &quot;133&quot;:
#                     return {&quot;color&quot;: &quot;#3f4889&quot;, &quot;fillColor&quot;: &quot;#3f4889&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;96&quot;: case &quot;116&quot;:
#                     return {&quot;color&quot;: &quot;#3a548c&quot;, &quot;fillColor&quot;: &quot;#3a548c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;104&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e308c58eb817f9f1dcd911db2b7631c2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e308c58eb817f9f1dcd911db2b7631c2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};

# %%
gdf_streets["density"] = gdf_streets["contains_kgiop_objects"] / gdf_streets.length

select_columns = []
gdf_streets.nlargest(5, "density")
# Out:
#                                                                       geometry  \
# Название улицы
# Ташкентская улица            MULTILINESTRING ((3374645.532 8375704.648, 337...
# площадь Московские Ворота    MULTILINESTRING ((3375093.549 8375550.330, 337...
# Детский переулок             MULTILINESTRING ((3375111.349 8376216.777, 337...
# Смоленская улица             MULTILINESTRING ((3375941.803 8378531.620, 337...
# Малая Митрофаньевская улица  MULTILINESTRING ((3373001.532 8376648.553, 337...
#
#                              contains_kgiop_objects   density
# Название улицы
# Ташкентская улица                                 5  0.007472
# площадь Московские Ворота                         2  0.007363
# Детский переулок                                  3  0.004917
# Смоленская улица                                  3  0.002542
# Малая Митрофаньевская улица                       6  0.002160

# %%
m = gdf_streets.explore("contains_kgiop_objects", tiles=TILES)
m = territory.explore(m=m, style_kwds={"fill": False, "weight": 5})

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75c18a4edb80830060b1ce71313364fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75c18a4edb80830060b1ce71313364fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_75c18a4edb80830060b1ce71313364fd = L.map(
#                 &quot;map_75c18a4edb80830060b1ce71313364fd&quot;,
#                 {
#                     center: [59.8282928, 30.29953855],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_75c18a4edb80830060b1ce71313364fd);
#
#
#
#
#
#             var tile_layer_0384b48de9eecc824b41720120ccc56c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_75c18a4edb80830060b1ce71313364fd);
#
#
#             map_75c18a4edb80830060b1ce71313364fd.fitBounds(
#                 [[59.743432999999996, 30.215627800000004], [59.9131526, 30.3834493]],
#                 {}
#             );
#
#
#         function geo_json_67926bb88873ac0344134c6d33471264_styler(feature) {
#             switch(feature.id) {
#                 case &quot;50&quot;: case &quot;55&quot;: case &quot;110&quot;: case &quot;137&quot;: case &quot;149&quot;: case &quot;151&quot;: case &quot;157&quot;: case &quot;160&quot;:
#                     return {&quot;color&quot;: &quot;#482071&quot;, &quot;fillColor&quot;: &quot;#482071&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;52&quot;: case &quot;67&quot;: case &quot;109&quot;: case &quot;112&quot;: case &quot;129&quot;: case &quot;132&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;153&quot;: case &quot;163&quot;: case &quot;166&quot;: case &quot;172&quot;:
#                     return {&quot;color&quot;: &quot;#471164&quot;, &quot;fillColor&quot;: &quot;#471164&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;68&quot;: case &quot;75&quot;: case &quot;90&quot;: case &quot;125&quot;:
#                     return {&quot;color&quot;: &quot;#472e7c&quot;, &quot;fillColor&quot;: &quot;#472e7c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;77&quot;: case &quot;119&quot;: case &quot;139&quot;: case &quot;145&quot;:
#                     return {&quot;color&quot;: &quot;#443b84&quot;, &quot;fillColor&quot;: &quot;#443b84&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;92&quot;: case &quot;105&quot;: case &quot;133&quot;:
#                     return {&quot;color&quot;: &quot;#3f4889&quot;, &quot;fillColor&quot;: &quot;#3f4889&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;96&quot;: case &quot;116&quot;:
#                     return {&quot;color&quot;: &quot;#3a548c&quot;, &quot;fillColor&quot;: &quot;#3a548c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;104&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_67926bb88873ac0344134c6d33471264_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_67926bb88873ac0344

# %%
#сохраняю датафрейм gdf_streets в файл streets_with_contains_kgiop.geojson в формате geojson
gdf_streets.to_file('streets_with_contains_kgiop.geojson', driver='GeoJSON')
